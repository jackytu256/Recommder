# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(io='../Recommder/Assignment 3.xls',sheetname=['movie-row','user-row','correlations'])

# %% [markdown]
# ## Part 1 - Without Normalization
#     dentify the top 5 neighbors

# %%
df['movie-row'].head()
# Out:
#                                                     1648  5136  918   2824  \
# 11: Star Wars: Episode IV - A New Hope (1977)        NaN   4.5   5.0   4.5
# 12: Finding Nemo (2003)                              NaN   5.0   5.0   NaN
# 13: Forrest Gump (1994)                              NaN   5.0   4.5   5.0
# 14: American Beauty (1999)                           NaN   4.0   NaN   NaN
# 22: Pirates of the Caribbean: The Curse of the ...   4.0   5.0   3.0   4.5
#
#                                                     3867  860   3712  2968  \
# 11: Star Wars: Episode IV - A New Hope (1977)        4.0   4.0   NaN   5.0
# 12: Finding Nemo (2003)                              4.0   4.0   4.5   4.5
# 13: Forrest Gump (1994)                              4.5   4.5   NaN   5.0
# 14: American Beauty (1999)                           NaN   NaN   4.5   2.0
# 22: Pirates of the Caribbean: The Curse of the ...   4.0   2.5   NaN   5.0
#
# ...

# %%
df['user-row'].head()
# Out:
#       11: Star Wars: Episode IV - A New Hope (1977)  12: Finding Nemo (2003)  \
# 1648                                            NaN                      NaN
# 5136                                            4.5                      5.0
# 918                                             5.0                      5.0
# 2824                                            4.5                      NaN
# 3867                                            4.0                      4.0
#
#       13: Forrest Gump (1994)  14: American Beauty (1999)  \
# 1648                      NaN                         NaN
# 5136                      5.0                         4.0
# 918                       4.5                         NaN
# 2824                      5.0                         NaN
# 3867                      4.5                         NaN
#
#       22: Pirates of the Caribbean: The Curse of the Black Pearl (2003)  \
# 1648                                                4.0
# ...

# %%
df['correlations']
# Out:
#           1648  5136  918   2824  3867  860   3712  2968  3525  4323  ...   \
# 1648       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5136       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 918        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2824       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3867       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 860        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3712       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2968       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3525  0.092775   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4323       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3617       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4360       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
users_corr = df['user-row'].transpose().corr().copy()
users_corr
# Out:
#           1648      5136      918       2824      3867      860       3712  \
# 1648  1.000000  0.402980 -0.142206  0.517620  0.300200  0.480537 -0.312412
# 5136  0.402980  1.000000  0.118979  0.057916  0.341734  0.241377  0.131398
# 918  -0.142206  0.118979  1.000000 -0.317063  0.294558  0.468333  0.092037
# 2824  0.517620  0.057916 -0.317063  1.000000 -0.060913 -0.008066  0.462910
# 3867  0.300200  0.341734  0.294558 -0.060913  1.000000  0.282497  0.400275
# 860   0.480537  0.241377  0.468333 -0.008066  0.282497  1.000000  0.171151
# 3712 -0.312412  0.131398  0.092037  0.462910  0.400275  0.171151  1.000000
# 2968  0.383348  0.206695 -0.045854  0.214760  0.264249  0.072927  0.065015
# 3525  0.092775  0.360056  0.367568  0.169907  0.125193  0.387133  0.095623
# 4323  0.098191  0.033642 -0.035394  0.119350 -0.333602  0.146158 -0.292501
# 3617 -0.041734  0.138548  0.011316  0.282756 -0.066576  0.219929 -0.038900
# ...

# %%
user_3712 = users_corr.sort(columns=[3712],ascending=[0])
user_3712
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           1648      5136      918       2824      3867      860       3712  \
# 3712 -0.312412  0.131398  0.092037  0.462910  0.400275  0.171151  1.000000
# 2824  0.517620  0.057916 -0.317063  1.000000 -0.060913 -0.008066  0.462910
# 3867  0.300200  0.341734  0.294558 -0.060913  1.000000  0.282497  0.400275
# 5062  0.551089  0.226635 -0.054762  0.259660  0.293868  0.311363  0.247693
# 442   0.022308  0.414438  0.304139  0.116532  0.113581  0.181276  0.227130
# 3853 -0.304422  0.189234  0.667168 -0.262073  0.464110  0.162314  0.193660
# 860   0.480537  0.241377  0.468333 -0.008066  0.282497  1.000000  0.171151
# 2486  0.002544  0.305803  0.133812  0.247097  0.438992  0.276306  0.166913
# 4942  0.116653  0.037769  0.015169  0.149247 -0.162818  0.079698  0.146011
# ...

# %%
user_3525 = users_corr.sort(columns=[3525 ],ascending=[0])
user_3525
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           1648      5136      918       2824      3867      860       3712  \
# 3525  0.092775  0.360056  0.367568  0.169907  0.125193  0.387133  0.095623
# 3556 -0.191988  0.488607  0.373226 -0.201275  0.174085  0.347470  0.016406
# 89    0.464610  0.562449  0.267029  0.241567 -0.003878  0.539066 -0.051320
# 860   0.480537  0.241377  0.468333 -0.008066  0.282497  1.000000  0.171151
# 918  -0.142206  0.118979  1.000000 -0.317063  0.294558  0.468333  0.092037
# 5136  0.402980  1.000000  0.118979  0.057916  0.341734  0.241377  0.131398
# 5261  0.493008  0.328120  0.470972  0.228341  0.297977  0.399436 -0.240764
# 5062  0.551089  0.226635 -0.054762  0.259660  0.293868  0.311363  0.247693
# 4809  0.394371  0.411676  0.082528  0.474974  0.054518  0.165608 -0.451625
# ...

# %%
user_3867 = users_corr.sort(columns=[3867],ascending=[0])
user_3867
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           1648      5136      918       2824      3867      860       3712  \
# 3867  0.300200  0.341734  0.294558 -0.060913  1.000000  0.282497  0.400275
# 2492  0.360644  0.422236  0.069956  0.238700  0.476683  0.207314 -0.115254
# 3853 -0.304422  0.189234  0.667168 -0.262073  0.464110  0.162314  0.193660
# 2486  0.002544  0.305803  0.133812  0.247097  0.438992  0.276306  0.166913
# 3712 -0.312412  0.131398  0.092037  0.462910  0.400275  0.171151  1.000000
# 2288  0.245048  0.390067  0.119162  0.166999  0.379856  0.279677  0.113266
# 5136  0.402980  1.000000  0.118979  0.057916  0.341734  0.241377  0.131398
# 2756  0.261268  0.148882  0.148431 -0.087747  0.310104  0.323499  0.126899
# 1648  1.000000  0.402980 -0.142206  0.517620  0.300200  0.480537 -0.312412
# ...

# %%
user_89 = users_corr.sort(columns=[89],ascending=[0])
user_89
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           1648      5136      918       2824      3867      860       3712  \
# 89    0.464610  0.562449  0.267029  0.241567 -0.003878  0.539066 -0.051320
# 4809  0.394371  0.411676  0.082528  0.474974  0.054518  0.165608 -0.451625
# 5136  0.402980  1.000000  0.118979  0.057916  0.341734  0.241377  0.131398
# 860   0.480537  0.241377  0.468333 -0.008066  0.282497  1.000000  0.171151
# 5062  0.551089  0.226635 -0.054762  0.259660  0.293868  0.311363  0.247693
# 3525  0.092775  0.360056  0.367568  0.169907  0.125193  0.387133  0.095623
# 1648  1.000000  0.402980 -0.142206  0.517620  0.300200  0.480537 -0.312412
# 2492  0.360644  0.422236  0.069956  0.238700  0.476683  0.207314 -0.115254
# 3556 -0.191988  0.488607  0.373226 -0.201275  0.174085  0.347470  0.016406
# ...

# %%
user_3712[3712][1:6]
# Out:
# 2824    0.462910
# 3867    0.400275
# 5062    0.247693
# 442     0.227130
# 3853    0.193660
# Name: 3712, dtype: float64

# %%
user_top_5_neighbors_For_3712=pd.DataFrame(np.array(np.split(np.tile(np.array(user_3712[3712][1:6]),len(top10movie_3712.columns)),len(top10movie_3712.columns))),index=top10movie_3712.columns,columns=top10movie_3712.index).transpose()
user_top_5_neighbors
# Out:
#       11: Star Wars: Episode IV - A New Hope (1977)  12: Finding Nemo (2003)  \
# 2824                                       0.462910                 0.462910
# 3867                                       0.400275                 0.400275
# 5062                                       0.247693                 0.247693
# 442                                        0.227130                 0.227130
# 3853                                       0.193660                 0.193660
#
#       13: Forrest Gump (1994)  14: American Beauty (1999)  \
# 2824                 0.462910                    0.462910
# 3867                 0.400275                    0.400275
# 5062                 0.247693                    0.247693
# 442                  0.227130                    0.227130
# 3853                 0.193660                    0.193660
#
#       22: Pirates of the Caribbean: The Curse of the Black Pearl (2003)  \
# 2824                                           0.462910
# ...

# %%
top5movie_3712 = df['movie-row'].ix[:,user_3712[3712][1:6].index].transpose().copy().fillna(0)
top5movie_3712
# Out:
#       11: Star Wars: Episode IV - A New Hope (1977)  12: Finding Nemo (2003)  \
# 2824                                            4.5                      0.0
# 3867                                            4.0                      4.0
# 5062                                            4.0                      4.0
# 442                                             3.0                      0.0
# 3853                                            0.0                      0.0
#
#       13: Forrest Gump (1994)  14: American Beauty (1999)  \
# 2824                      5.0                         0.0
# 3867                      4.5                         0.0
# 5062                      4.5                         4.5
# 442                       3.0                         4.0
# 3853                      3.5                         0.0
#
#       22: Pirates of the Caribbean: The Curse of the Black Pearl (2003)  \
# 2824                                                4.5
# ...

# %%
top5movie_3712['641: Requiem for a Dream (2000)']
top5movie_3712['603: The Matrix (1999)'].sum()/5
top5movie_3712['105: Back to the Future (1985)']
# Out:
# 2824    0.0
# 3867    0.0
# 5062    4.5
# 442     5.0
# 3853    0.0
# Name: 105: Back to the Future (1985), dtype: float64

# %%
user_top_5_Rating_Mean_For_3712 = pd.DataFrame(np.array(np.split(np.tile(np.array(top5movie_3712.transpose().describe().ix['mean',:].tolist()),len(top10movie_3712.columns)),len(top10movie_3712.columns))),index=top10movie_3712.columns,columns=top10movie_3712.index).transpose()
user_top_5_Rating_Mean_For_3712
# Out:
#       11: Star Wars: Episode IV - A New Hope (1977)  12: Finding Nemo (2003)  \
# 2824                                          1.380                    1.380
# 3867                                          2.380                    2.380
# 5062                                          2.590                    2.590
# 442                                           2.520                    2.520
# 3853                                          1.665                    1.665
#
#       13: Forrest Gump (1994)  14: American Beauty (1999)  \
# 2824                    1.380                       1.380
# 3867                    2.380                       2.380
# 5062                    2.590                       2.590
# 442                     2.520                       2.520
# 3853                    1.665                       1.665
#
#       22: Pirates of the Caribbean: The Curse of the Black Pearl (2003)  \
# 2824                                              1.380
# ...

# %%
df['movie-row'].ix[:,user_3712[3712][1:6].index].transpose().describe().ix['mean',:]
# Out:
# 11: Star Wars: Episode IV - A New Hope (1977)                                         3.875000
# 12: Finding Nemo (2003)                                                               4.000000
# 13: Forrest Gump (1994)                                                               4.100000
# 14: American Beauty (1999)                                                            4.250000
# 22: Pirates of the Caribbean: The Curse of the Black Pearl (2003)                     3.375000
# 24: Kill Bill: Vol. 1 (2003)                                                          4.200000
# 38: Eternal Sunshine of the Spotless Mind (2004)                                      4.000000
# 63: Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                         3.000000
# 77: Memento (2000)                                                                    4.375000
# 85: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    4.375000
# ...

# %%
top10movie_3712_sorted = pd.DataFrame(df['movie-row'].ix[:,user_3712[3712][1:6].index].transpose().describe().ix['mean',:])
top10movie_3712_sorted
# Out:
#                                                         mean
# 11: Star Wars: Episode IV - A New Hope (1977)       3.875000
# 12: Finding Nemo (2003)                             4.000000
# 13: Forrest Gump (1994)                             4.100000
# 14: American Beauty (1999)                          4.250000
# 22: Pirates of the Caribbean: The Curse of the ...  3.375000
# 24: Kill Bill: Vol. 1 (2003)                        4.200000
# 38: Eternal Sunshine of the Spotless Mind (2004)    4.000000
# 63: Twelve Monkeys (a.k.a. 12 Monkeys) (1995)       3.000000
# 77: Memento (2000)                                  4.375000
# 85: Raiders of the Lost Ark (Indiana Jones and ...  4.375000
# 98: Gladiator (2000)                                4.000000
# 105: Back to the Future (1985)                      4.750000
# 107: Snatch (2000)                                  4.500000
# 114: Pretty Woman (1990)                            4.000000
# ...

# %%
top10movie_3712_sorted= top10movie_3712_sorted.sort(['mean'],ascending=[0])
top10movie_3712_sorted
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                         mean
# 641: Requiem for a Dream (2000)                     5.000000
# 603: The Matrix (1999)                              4.800000
# 105: Back to the Future (1985)                      4.750000
# 121: The Lord of the Rings: The Two Towers (2002)   4.700000
# 120: The Lord of the Rings: The Fellowship of t...  4.700000
# 122: The Lord of the Rings: The Return of the K...  4.600000
# 155: The Dark Knight (2008)                         4.500000
# 107: Snatch (2000)                                  4.500000
# 85: Raiders of the Lost Ark (Indiana Jones and ...  4.375000
# 77: Memento (2000)                                  4.375000
# 1572: Die Hard: With a Vengeance (1995)             4.333333
# ...

# %%
pd.DataFrame(df['movie-row'].ix[:,user_3525[3525][1:6].index].transpose().describe().ix['mean',:]).sort(['mean'],ascending=[0])
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                         mean
# 194: Amelie (2001)                                  5.000000
# 238: The Godfather (1972)                           5.000000
# 38: Eternal Sunshine of the Spotless Mind (2004)    5.000000
# 275: Fargo (1996)                                   4.833333
# 807: Seven (a.k.a. Se7en) (1995)                    4.833333
# 8587: The Lion King (1994)                          4.750000
# 77: Memento (2000)                                  4.750000
# 424: Schindler's List (1993)                        4.750000
# 585: Monsters Inc. (2001)                           4.750000
# 105: Back to the Future (1985)                      4.700000
# 278: The Shawshank Redemption (1994)                4.666667
# ...

# %% [markdown]
# ## get top5 neighbor for 3867 and 89

# %%
pd.DataFrame(df['movie-row'].ix[:,user_3867[3867][1:6].index].transpose().describe().ix['mean',:]).sort(['mean'],ascending=[0])
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                         mean
# 1891: Star Wars: Episode V - The Empire Strikes...  4.750000
# 77: Memento (2000)                                  4.500000
# 155: The Dark Knight (2008)                         4.500000
# 122: The Lord of the Rings: The Return of the K...  4.500000
# 603: The Matrix (1999)                              4.400000
# 121: The Lord of the Rings: The Two Towers (2002)   4.400000
# 585: Monsters Inc. (2001)                           4.375000
# 807: Seven (a.k.a. Se7en) (1995)                    4.333333
# 120: The Lord of the Rings: The Fellowship of t...  4.300000
# 238: The Godfather (1972)                           4.250000
# 194: Amelie (2001)                                  4.166667
# ...

# %%
pd.DataFrame(df['movie-row'].ix[:,user_89[89][1:6].index].transpose().describe().ix['mean',:]).sort(['mean'],ascending=[0])
# Out:
# /Users/tuhung-te/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                         mean
# 238: The Godfather (1972)                           4.875000
# 278: The Shawshank Redemption (1994)                4.875000
# 424: Schindler's List (1993)                        4.750000
# 275: Fargo (1996)                                   4.750000
# 807: Seven (a.k.a. Se7en) (1995)                    4.750000
# 122: The Lord of the Rings: The Return of the K...  4.666667
# 13: Forrest Gump (1994)                             4.600000
# 38: Eternal Sunshine of the Spotless Mind (2004)    4.500000
# 274: The Silence of the Lambs (1991)                4.500000
# 8587: The Lion King (1994)                          4.500000
# 550: Fight Club (1999)                              4.500000
# ...

# %% [markdown]
# ## Part 2 - Normalization
